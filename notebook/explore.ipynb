# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/stroke_data.csv")
df.head(10)

# %%
print(len(df))

# %%
df.describe()
df.isnull().sum()

# %%
df['smoking_status'].value_counts()

# %%
df['work_type'].unique()

# %%
print( df['avg_glucose_level'].max())
print( df['avg_glucose_level'].min())

# %%
range_glocuse = df['avg_glucose_level'].max() - df['avg_glucose_level'].min()
print(range_glocuse)

# %%
num_below70 = df[df['avg_glucose_level'] < 70].value_counts()
print(len(num_below70))
